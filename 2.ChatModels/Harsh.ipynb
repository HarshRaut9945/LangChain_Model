# %% [markdown]
# # Gemni Api

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv


load_dotenv()


model=ChatGoogleGenerativeAI(model='gemini-2.5-flash',google_api_key=os.getenv('GOOGLE_API_KEY'))

user_querry="How far earth is from sun"

output=model.invoke(user_querry).content

print(output)
# Out:
# The Earth's distance from the Sun isn't constant because Earth orbits the Sun in an **ellipse**, not a perfect circle.
#
# Here's a breakdown:
#
# 1.  **Average Distance:**
#     *   **149.6 million kilometers (km)**
#     *   **92.96 million miles**
#
# 2.  **Astronomical Unit (AU):**
#     *   This average distance is defined as **1 Astronomical Unit (AU)**. The AU is a standard unit of measurement used by astronomers for distances within our solar system.
#
# 3.  **Varying Distance:**
#     *   **Perihelion:** The closest point Earth gets to the Sun (around January 3rd).
#         *   Approximately **147.1 million km** (91.4 million miles)
#     *   **Aphelion:** The farthest point Earth gets from the Sun (around July 4th).
#         *   Approximately **152.1 million km** (94.5 million miles)
#
# So, while the distance fluctuates throughout the year, the most commonly cited figure is the average distance of about **150 million kilometers (93 million miles)**, or **1 AU**.
